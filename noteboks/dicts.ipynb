# %%
import pickle
import csv
from io import StringIO

# %%
# Dicionários que você deseja salvar
candles_dict = {
    'threshold_dict': {
        'doji_threshold': 0.002,
        'bullish_threshold': 0.005,
        'bearish_threshold': 0.005,
        'volatility_window': 7
    }
}

morning_star_dict = {
    'morning_star_dict': {
        'doji_threshold': 0.002,
         'bullish_threshold': 0.3,
        'bearish_threshold': 0.2,
        'volatility_window': 7
    }
}

rolling_cross_dict = {
    'rolling_cross_dict':
        {'sma_5_l0': {'short': 5, 'long': 10},
        'sma_5_20': {'short': 5, 'long': 20},
        'sma_10_30': {'short': 10, 'long': 30},
        'sma_10_50': {'short': 10, 'long': 50},
        'sma_20_50': {'short': 20, 'long': 50},
        'sma_20_100': {'short': 20, 'long': 100},
        'sma_50_100': {'short': 50, 'long': 100},
        'sma_50_150': {'short': 50, 'long': 150},
        'sma_100_200': {'short': 100, 'long': 200},
        'ema_5_10': {'short': 5, 'long': 10},
        'ema_5_20': {'short': 5, 'long': 20},
        'ema_10_30': {'short': 10, 'long': 30},
        'ema_10_50': {'short': 10, 'long': 50},
        'ema_20_50': {'short': 20, 'long': 50},
        'ema_20_100': {'short': 20, 'long': 100},
        'ema_50_100': {'short': 50, 'long': 100},
        'ema_50_150': {'short': 50, 'long': 150},
        'ema_100_200': {'short': 100, 'long': 200},
        'macd_9_12': {'short': 12, 'long': 26},
        'macd_9_30': {'short': 30, 'long': 60},
        'macd_12_26': {'short': 12, 'long': 26},
        'macd_12_50': {'short': 12, 'long': 50},
        'macd_26_50': {'short': 26, 'long': 50},
        'macd_26_100': {'short': 26, 'long': 100},
        'macd_50_100': {'short': 50, 'long': 100},
        'macd_50_200': {'short': 50, 'long': 200}
    }
}


dicts = [candles_dict, morning_star_dict, rolling_cross_dict]

with open('..//pkl//threshold_dicts.pkl', 'wb') as file:
    pickle.dump(dicts, file)

print("Candles Dictionary:", candles_dict)
print("Morning Star Dictionary:", morning_star_dict)
print("rolling_cross_dict", rolling_cross_dict)

# %%
candle_patterns_info = {
        "Doji": {
        "Type": "neutral",
        "Image": "doji.png",
        "Definition": "A doji has a very small body with shadows of varying lengths on both sides. It represents indecision in the market.",
        "Significance": "Shows uncertainty in the market and potential reversal or continuation depending on previous trends.",
        "Confidence": "weak"
    },
        
    "Marubozu": {
        "Type": "bullish",
        "Image": "marubozu.png",
        "Definition": "A Marubozu candle has a long body with no shadows. The opening and closing prices are the highest and lowest points respectively.",
        "Significance": "Indicates strong momentum in the direction of the body (bullish or bearish).",
        "Confidence": "strong"
    },
    
    "Bearish Hammer": {
        "Type": "bearish",
        "Image": "bearish_hammer.png",
        "Definition": "A bearish hammer has a small body at the top of the candle with a long lower shadow. It occurs after an uptrend and indicates a potential reversal.",
        "Significance": "Suggests that sellers have taken control, and a downtrend may follow.",
        "Confidence": "moderate"
    },
    "Bearish Harami": {
        "Type": "bearish",
        "Image": "bearish_harami.png",
        "Definition": "A bearish harami consists of a large bullish candle followed by a smaller bearish candle that is completely contained within the body of the first candle.",
        "Significance": "Indicates a potential reversal or weakening of the uptrend.",
        "Confidence": "moderate"
    },
    "Bearish Engulfing": {
        "Type": "bearish",
        "Image": "bearish_engulfing.png",
        "Definition": "A bearish engulfing pattern occurs when a large bearish candle completely engulfs the previous smaller bullish candle.",
        "Significance": "Signals a strong potential reversal from uptrend to downtrend.",
        "Confidence": "strong"
    },
    "Homing Pigeon": {
        "Type": "bearish",
        "Image": "homing_pigeon.png",
        "Definition": "A homing pigeon pattern consists of a large bearish candle followed by a smaller bearish candle that closes within the body of the first candle.",
        "Significance": "Indicates that selling pressure is increasing, and a further decline may be expected.",
        "Confidence": "moderate"
    },
    "High Wave": {
        "Type": "sideways",
        "Image": "high_wave.png",
        "Definition": "A high wave candle has a small body with long upper and lower shadows. It shows indecision in the market.",
        "Significance": "Indicates uncertainty and can signal potential reversal or consolidation.",
        "Confidence": "weak"
    },
    "Harami Cross (Bearish)": {
        "Type": "bearish",
        "Image": "harami_cross_bearish.png",
        "Definition": "A harami cross is a variation of the harami pattern, where the second candle is a doji (a candle with no body). In a bearish harami cross, it follows a large bullish candle.",
        "Significance": "Suggests a potential reversal or weakening of the uptrend.",
        "Confidence": "moderate"
    },
    "Identical Three Crows": {
        "Type": "bearish",
        "Image": "identical_three_crows.png",
        "Definition": "This pattern consists of three consecutive bearish candles of similar size, with each subsequent candle opening within the body of the previous one.",
        "Significance": "Indicates a strong bearish trend and potential continuation.",
        "Confidence": "strong"
    },
    "In Neck": {
        "Type": "bearish",
        "Image": "in_neck.png",
        "Definition": "In the in-neck pattern, a bearish candle follows a bullish candle and closes just below the closing price of the bullish candle.",
        "Significance": "Suggests a potential bearish reversal or continuation of the downtrend.",
        "Confidence": "weak"
    },
    "Kicking (Bearish)": {
        "Type": "bearish",
        "Image": "kicking_bearish.png",
        "Definition": "The kicking pattern consists of a bullish candle followed by a large bearish candle, with the open of the bearish candle gapping below the close of the bullish candle.",
        "Significance": "Indicates a strong bearish reversal.",
        "Confidence": "strong"
    },
    "Meeting Lines (bearish)": {
        "Type": "bearish",
        "Image": "meeting_lines_bearish.png",
        "Definition": "Meeting lines consist of a bullish candle followed by a bearish candle that opens at the close of the bullish candle and closes at the same level as the open of the bullish candle.",
        "Significance": "Signals a potential reversal or weakening of the uptrend.",
        "Confidence": "weak"
    },
    "Matching Low": {
        "Type": "bearish",
        "Image": "matching_low.png",
        "Definition": "A matching low pattern occurs when two consecutive candles have the same low price, with the second being bearish.",
        "Significance": "Suggests potential bearish reversal or continuation.",
        "Confidence": "moderate"
    },
    "On Neck": {
        "Type": "bearish",
        "Image": "on_neck.png",
        "Definition": "The on-neck pattern consists of a bearish candle following a bullish candle, closing just below the closing price of the bullish candle.",
        "Significance": "Indicates potential bearish reversal or continuation.",
        "Confidence": "weak"
    },
    "Stick Sandwich": {
        "Type": "bearish",
        "Image": "stick_sandwich.png",
        "Definition": "A stick sandwich pattern consists of a large bearish candle, followed by a small bullish candle, and then another large bearish candle.",
        "Significance": "Indicates a potential bearish reversal or continuation.",
        "Confidence": "moderate"
    },
    "Pierching (Bearish)": {
        "Type": "bearish",
        "Image": "pierching_bearish.png",
        "Definition": "The bearish piercing pattern occurs when a bearish candle follows a bullish candle and the bearish candle's close is above the midpoint of the bullish candle.",
        "Significance": "Suggests a potential bearish reversal or weakening of the uptrend.",
        "Confidence": "moderate"
    },
    "Separating Lines (Bearish)": {
        "Type": "bearish",
        "Image": "separating_lines_bearish.png",
        "Definition": "In the separating lines pattern, a bearish candle follows a bullish candle, with the open of the bearish candle being at the close of the bullish candle.",
        "Significance": "Indicates a potential bearish reversal.",
        "Confidence": "moderate"
    },
    "Shooting Star": {
        "Type": "bearish",
        "Image": "shooting_star.png",
        "Definition": "A shooting star has a small body at the bottom of the trading range with a long upper shadow, appearing after an uptrend.",
        "Significance": "Indicates a potential bearish reversal.",
        "Confidence": "strong"
    },
    "Three Black Crows": {
        "Type": "bearish",
        "Image": "three_black_crows.png",
        "Definition": "The three black crows pattern consists of three consecutive bearish candles, each opening within the body of the previous one and closing at or near the low.",
        "Significance": "Signals a strong bearish trend and potential continuation.",
        "Confidence": "strong"
    },
    "Three Inside Down": {
        "Type": "bearish",
        "Image": "three_inside_down.png",
        "Definition": "The three inside down pattern includes a bullish candle, followed by a small candle that is within the range of the first, and then a bearish candle that closes below the low of the first candle.",
        "Significance": "Indicates a potential bearish reversal.",
        "Confidence": "moderate"
    },
    "Three Outside Down": {
        "Type": "bearish",
        "Image": "three_outside_down.png",
        "Definition": "The three outside down pattern includes a large bullish candle, followed by a bearish candle that fully engulfs the previous candle, and another bearish candle that continues the downtrend.",
        "Significance": "Suggests a strong bearish reversal.",
        "Confidence": "strong"
    },
    "Unique Three River Bottom": {
        "Type": "bullish",
        "Image": "unique_three_river_bottom.png",
        "Definition": "This pattern involves three candles: the first is a large bearish candle, the second is a small doji or spinning top, and the third is a bullish candle that closes above the high of the first candle.",
        "Significance": "Indicates a potential bullish reversal after a downtrend.",
        "Confidence": "moderate"
    },
    "Tri-Star Bearish": {
        "Type": "bearish",
        "Image": "tri_star_bearish.png",
        "Definition": "The tri-star bearish pattern consists of three consecutive doji candles, with the middle doji forming at the top of an uptrend.",
        "Significance": "Suggests a potential bearish reversal.",
        "Confidence": "moderate"
    },
    "Tweezers Bottom": {
        "Type": "bullish",
        "Image": "tweezers_bottom.png",
        "Definition": "A tweezers bottom pattern occurs when two consecutive candles have the same low price, with the second being bullish.",
        "Significance": "Indicates a potential bullish reversal.",
        "Confidence": "moderate"
    },
    "Two Black Gapping": {
        "Type": "bearish",
        "Image": "two_black_gapping.png",
        "Definition": "The two black gapping pattern involves two consecutive bearish candles with a gap between them, where the second candle opens below the close of the first candle.",
        "Significance": "Suggests a strong bearish trend.",
        "Confidence": "strong"
    },
     "Two Crows": {
        "Type": "bearish",
        "Image": "two_crows.png",
        "Definition": "The two crows pattern consists of a bullish candle followed by two consecutive bearish candles, with each bearish candle opening within the body of the previous candle.",
        "Significance": "Indicates a potential bearish reversal or continuation.",
        "Confidence": "moderate"
    },
    "Window Falling": {
        "Type": "bearish",
        "Image": "window_falling.png",
        "Definition": "A window falling pattern involves a gap down after a previous uptrend, followed by bearish candles.",
        "Significance": "Indicates a strong bearish trend.",
        "Confidence": "strong"
    },
    "Hammer": {
        "Type": "bullish",
        "Image": "hammer.png",
        "Definition": "A hammer has a small body at the top of the candle with a long lower shadow. It occurs after a downtrend and indicates a potential reversal.",
        "Significance": "Suggests that buyers are gaining control, and an uptrend may follow.",
        "Confidence": "moderate"
    },
    "Hanging Man": {
        "Type": "bearish",
        "Image": "hanging_man.png",
        "Definition": "A hanging man has a small body at the top of the candle with a long lower shadow. It occurs after an uptrend and suggests a potential reversal.",
        "Significance": "Indicates that selling pressure is increasing and a downtrend may follow.",
        "Confidence": "moderate"
    },
    "Ladder Bottom": {
        "Type": "bullish",
        "Image": "ladder_bottom.png",
        "Definition": "A ladder bottom pattern consists of three or more candles with long lower shadows and small bodies, indicating a potential reversal.",
        "Significance": "Signals a strong bullish reversal.",
        "Confidence": "strong"
    },
    "Three Line Strike Bullish": {
        "Type": "bullish",
        "Image": "three_line_strike_bullish.png",
        "Definition": "The three line strike bullish pattern consists of three consecutive bullish candles followed by a bearish candle that completely engulfs the previous three candles.",
        "Significance": "Indicates a strong bullish trend and continuation.",
        "Confidence": "strong"
    },
    "Harami Bullish": {
        "Type": "bullish",
        "Image": "harami_bullish.png",
        "Definition": "A bullish harami consists of a large bearish candle followed by a smaller bullish candle that is completely contained within the body of the first candle.",
        "Significance": "Indicates a potential reversal or weakening of the downtrend.",
        "Confidence": "moderate"
    },
    "Morning Doji Star": {
        "Type": "bullish",
        "Image": "morning_doji_star.png",
        "Definition": "A morning doji star pattern includes a long bearish candle, a doji, and a long bullish candle, signaling a reversal from bearish to bullish.",
        "Significance": "Indicates a potential bullish reversal.",
        "Confidence": "strong"
    },
    "Morning Star": {
        "Type": "bullish",
        "Image": "morning_star.png",
        "Definition": "A morning star pattern consists of a large bearish candle, a small-bodied candle, and a large bullish candle, suggesting a reversal from a downtrend to an uptrend.",
        "Significance": "Indicates a potential bullish reversal.",
        "Confidence": "strong"
    },
    "Kicking (Bullish)": {
        "Type": "bullish",
        "Image": "kicking_bullish.png",
        "Definition": "The kicking pattern consists of a bearish candle followed by a large bullish candle, with the open of the bullish candle gapping above the close of the bearish candle.",
        "Significance": "Indicates a strong bullish reversal.",
        "Confidence": "strong"
    },
    "Mat Hold": {
        "Type": "bullish",
        "Image": "mat_hold.png",
        "Definition": "The mat hold pattern consists of a large bullish candle followed by a series of smaller candles, then another large bullish candle, indicating a continuation of the uptrend.",
        "Significance": "Suggests a strong bullish trend and continuation.",
        "Confidence": "strong"
    },
    "Meeting Lines (Bullish)": {
        "Type": "bullish",
        "Image": "meeting_lines_bullish.png",
        "Definition": "Meeting lines consist of a bearish candle followed by a bullish candle that opens at the close of the bearish candle and closes at the same level as the open of the bearish candle.",
        "Significance": "Signals a potential reversal or weakening of the downtrend.",
        "Confidence": "moderate"
    },
    "Pierching (Bullish)": {
        "Type": "bullish",
        "Image": "pierching_bullish.png",
        "Definition": "The bullish piercing pattern occurs when a bullish candle follows a bearish candle and the bullish candle's close is above the midpoint of the bearish candle.",
        "Significance": "Indicates a potential bullish reversal or weakening of the downtrend.",
        "Confidence": "moderate"
    },
    "Side by Side White Lines (Bullish)": {
        "Type": "bullish",
        "Image": "side_by_side_white_lines_bullish.png",
        "Definition": "This pattern consists of two consecutive bullish candles with the same open and close prices, indicating strong buying pressure.",
        "Significance": "Signals a strong bullish trend and continuation.",
        "Confidence": "strong"
    },
    "Rising Three Methods": {
        "Type": "bullish",
        "Image": "rising_three_methods.png",
        "Definition": "The rising three methods pattern includes a long bullish candle, followed by three small-bodied candles, and then another long bullish candle, indicating a continuation of the uptrend.",
        "Significance": "Indicates a strong bullish trend and continuation.",
        "Confidence": "strong"
    },
    "Three White Soldiers": {
        "Type": "bullish",
        "Image": "three_white_soldiers.png",
        "Definition": "The three white soldiers pattern consists of three consecutive bullish candles, each opening within the body of the previous one and closing near the high.",
        "Significance": "Signals a strong bullish trend and potential continuation.",
        "Confidence": "strong"
    },
    "Separating Lines (Bullish)": {
        "Type": "bullish",
        "Image": "separating_lines_bullish.png",
        "Definition": "In the separating lines pattern, a bullish candle follows a bearish candle, with the open of the bullish candle being at the close of the bearish candle.",
        "Significance": "Indicates a potential bullish reversal.",
        "Confidence": "moderate"
    },
    "Upside Tasuki Gap": {
        "Type": "bullish",
        "Image": "upside_tasuki_gap.png",
        "Definition": "An upside tasuki gap consists of a bullish candle, a gap up, and another bullish candle, indicating a continuation of the uptrend.",
        "Significance": "Signals a strong bullish trend and continuation.",
        "Confidence": "strong"
    },
    "Three Inside Up": {
        "Type": "bullish",
        "Image": "three_inside_up.png",
        "Definition": "The three inside up pattern includes a bearish candle, followed by a small candle within the range of the first, and then a bullish candle that closes above the high of the first candle.",
        "Significance": "Indicates a potential bullish reversal.",
        "Confidence": "moderate"
    },
    "Three Outside Up": {
        "Type": "bullish",
        "Image": "three_outside_up.png",
        "Definition": "The three outside up pattern includes a large bearish candle, followed by a bullish candle that fully engulfs the previous candle, and another bullish candle that continues the uptrend.",
        "Significance": "Suggests a strong bullish reversal.",
        "Confidence": "strong"
    },
    "Tri-Star Bullish": {
        "Type": "bullish",
        "Image": "tri_star_bullish.png",
        "Definition": "The tri-star bullish pattern consists of three consecutive doji candles, with the middle doji forming at the bottom of a downtrend.",
        "Significance": "Indicates a potential bullish reversal.",
        "Confidence": "moderate"
    },
    "Three Stars in the South": {
        "Type": "bullish",
        "Image": "three_star_in_the_south.png",
        "Definition": "The three stars in the south pattern consists of three consecutive candles, typically with small bodies and long lower shadows, indicating a potential reversal from bearish to bullish.",
        "Significance": "Indicates a potential bullish reversal.",
        "Confidence": "moderate"
    },
    "Upside Gap Two Crows": {
        "Type": "bearish",
        "Image": "upside_gap_two_crows.png",
        "Definition": "The upside gap two crows pattern consists of a large bullish candle, followed by a gap up and then two bearish candles.",
        "Significance": "Indicates a potential bearish reversal after a strong uptrend.",
        "Confidence": "moderate"
    },
    "Tweezers Top": {
        "Type": "bearish",
        "Image": "tweezers_top.png",
        "Definition": "A tweezer top pattern occurs when two consecutive candles have the same high price, with the second being bearish.",
        "Significance": "Indicates a potential bearish reversal.",
        "Confidence": "moderate"
    },
    "Evening Doji Star": {
        "Type": "bearish",
        "Image": "evening_doji_star.png",
        "Definition": "An evening doji star pattern consists of a large bullish candle, a doji, and a large bearish candle, signaling a reversal from bullish to bearish.",
        "Significance": "Indicates a potential bearish reversal.",
        "Confidence": "strong"
    }
}

# %%
def sort_patterns(patterns_info):
    # Ordenar por tipo e depois por confiança
    sorted_patterns = {}
    
    # Mapeia os níveis de confiança para sua ordem
    confidence_order = {'strong': 1, 'moderate': 2, 'weak': 3}
    
    # Divide os padrões em bearish e bullish
    bearish_patterns = {k: v for k, v in patterns_info.items() if v['Type'] == 'bearish'}
    bullish_patterns = {k: v for k, v in patterns_info.items() if v['Type'] == 'bullish'}
    
    # Ordena os padrões de acordo com a confiança
    sorted_bearish = sorted(bearish_patterns.items(), key=lambda x: confidence_order[x[1]['Confidence']])
    sorted_bullish = sorted(bullish_patterns.items(), key=lambda x: confidence_order[x[1]['Confidence']])
    
    # Adiciona os padrões organizados ao dicionário final
    sorted_patterns.update(dict(sorted_bearish))
    sorted_patterns.update(dict(sorted_bullish))
    
    return sorted_patterns

# Ordena os padrões de velas
sorted_candle_patterns_info = sort_patterns(candle_patterns_info)

# %%
for key in candle_patterns_info.keys():
    if key not in sorted_candle_patterns_info.keys():
        print(key)

# %%
sorted_candle_patterns_info.update({
    "High Wave": {
        "Type": "sideways",
        "Image": "high_wave.png",
        "Definition": "A high wave candle has a small body with long upper and lower shadows. It shows indecision in the market.",
        "Significance": "Indicates uncertainty and can signal potential reversal or consolidation.",
        "Confidence": "weak",
        
           "Doji": {
        "Type": "neutral",
        "Image": "doji.png",
        "Definition": "A doji has a very small body with shadows of varying lengths on both sides. It represents indecision in the market.",
        "Significance": "Shows uncertainty in the market and potential reversal or continuation depending on previous trends.",
        "Confidence": "weak"
    },
        
    "Marubozu": {
        "Type": "bullish",
        "Image": "marubozu.png",
        "Definition": "A Marubozu candle has a long body with no shadows. The opening and closing prices are the highest and lowest points respectively.",
        "Significance": "Indicates strong momentum in the direction of the body (bullish or bearish).",
        "Confidence": "strong"
    },
    }
})

# %%
len(sorted_candle_patterns_info)

# %%
with open('..//pkl//candle_patterns_info.pkl', 'wb') as file:
    pickle.dump(sorted_candle_patterns_info, file)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

def plot_normalized_candlestick(candle_vectors):
    fig, ax = plt.subplots(figsize=(6, 8))  # Aumentando o tamanho para um esquema visual mais destacado
    width = 0.2 
    spacing = 0.4 

    for i in range(len(candle_vectors)):
        candle_vector = candle_vectors[i]
        adjusted_open, adjusted_high, adjusted_low, adjusted_close = candle_vector
        
        x = i * spacing
        
        lower_shadow_min = min(adjusted_open, adjusted_close)
        ax.plot([x, x], [adjusted_low, lower_shadow_min], color='black', linewidth=1)
        
        upper_shadow_max = max(adjusted_open, adjusted_close)
        ax.plot([x, x], [upper_shadow_max, adjusted_high], color='black', linewidth=1)
        
        color = 'green' if adjusted_close - adjusted_open >= 0 else 'red'
        
        # Desenho do corpo do candle
        rect = patches.Rectangle(
            (x - width / 2, min(adjusted_open, adjusted_close)), 
            width, 
            abs(adjusted_open - adjusted_close), 
            linewidth=0, 
            edgecolor='white', 
            facecolor=color
        )
        ax.add_patch(rect)

        # Anotações com texto grande para um esquema visual destacado
        ax.text(x, adjusted_open, 'Open', ha='center', va='center', fontsize=12, color='black', weight='bold')
        ax.text(x, adjusted_high, 'High', ha='center', va='center', fontsize=12, color='black', weight='bold')
        ax.text(x, adjusted_low, 'Low', ha='center', va='center', fontsize=12, color='black', weight='bold')
        ax.text(x, (adjusted_open + adjusted_close) / 2, 'Body', ha='center', va='center', fontsize=12, color='black', weight='bold')
    
    margin = 0.1 
    
    adjusted_max_high = max([candle[1] for candle in candle_vectors])
    adjusted_min_low = min([candle[2] for candle in candle_vectors])
    
    ax.set_xlim(-width, len(candle_vectors) * spacing)
    ax.set_ylim(adjusted_min_low - margin, adjusted_max_high + margin)
    ax.grid(False)
    ax.set_xticks([])  
    ax.set_yticks([]) 
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

    plt.show()

# Exemplo de dados de candlestick
candle_vectors = [
    (100, 115, 95, 110),  # Bullish candle
    (110, 115, 95, 100)   # Bearish candle
]

# Chamada da função para exibir o gráfico
plot_normalized_candlestick(candle_vectors)

# %%
bullish_candles_info.keys()

# %%
bearish_candles_info.update({
    "Bearish Engulfing": {
        "Definition": "A bearish engulfing pattern occurs when a large bearish candle completely engulfs the previous smaller bullish candle.",
        "Significance": "Signals a strong potential reversal from uptrend to downtrend."
    },
    "Unique Three River Bottom": {
        "Definition": "This pattern involves three candles: the first is a large bearish candle, the second is a small doji or spinning top, and the third is a bullish candle that closes above the high of the first candle.",
        "Significance": "Indicates a potential bullish reversal after a downtrend."
    },
    "Two Black Gapping": {
        "Definition": "The two black gapping pattern involves two consecutive bearish candles with a gap between them, where the second candle opens below the close of the first candle.",
        "Significance": "Suggests a strong bearish trend."
    },
    "Two Crows": {
        "Definition": "The two crows pattern consists of a bullish candle followed by two consecutive bearish candles, with each bearish candle opening within the body of the previous candle.",
        "Significance": "Indicates a potential bearish reversal or continuation."
    }
})

# Adicionar chaves faltantes no dicionário de informações bullish
bullish_candles_info.update({
    "Harami Bullish": {
        "Definition": "A bullish harami consists of a large bearish candle followed by a smaller bullish candle that is completely contained within the body of the first candle.",
        "Significance": "Indicates a potential reversal or weakening of the downtrend."
    },
    "Rising Three Methods": {
        "Definition": "The rising three methods pattern includes a long bullish candle, followed by three small-bodied candles, and then another long bullish candle, indicating a continuation of the uptrend.",
        "Significance": "Indicates a strong bullish trend and continuation."
    },
    "Upside Tasuki Gap": {
        "Definition": "An upside tasuki gap consists of a bullish candle, a gap up, and another bullish candle, indicating a continuation of the uptrend.",
        "Significance": "Signals a strong bullish trend and continuation."
    },
    "Three Stars in the South": {
        "Definition": "The three stars in the south pattern includes three consecutive doji candles, signaling a potential reversal from bearish to bullish.",
        "Significance": "Indicates a potential bullish reversal."
    },
    "Upside Gap Two Crows": {
        "Definition": "The upside gap two crows pattern consists of a large bullish candle, followed by a gap up and then two bearish candles.",
        "Significance": "Indicates a potential bearish reversal after a strong uptrend."
    },
    "Tweezer Top": {
        "Definition": "A tweezer top pattern occurs when two consecutive candles have the same high price, with the second being bearish.",
        "Significance": "Indicates a potential bearish reversal."
    },
    "Window Rising": {
        "Definition": "A window rising pattern involves a gap up after a previous downtrend, followed by bullish candles.",
        "Significance": "Indicates a strong bullish trend."
    }
})
