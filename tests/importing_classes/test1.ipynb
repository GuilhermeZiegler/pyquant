# %%
import sys
import os

# Adicione o caminho absoluto correto para o diretório scripts
script_path = os.path.abspath(os.path.join('..', '..', 'scripts'))
if script_path not in sys.path:
    sys.path.append(script_path)

print(sys.path)
# Out:
# ['c:\\Users\\guitz\\OneDrive\\Área de Trabalho\\pyquant\\pyquant\\tests\\importing_classes', 'c:\\Users\\guitz\\anaconda3\\python311.zip', 'c:\\Users\\guitz\\anaconda3\\DLLs', 'c:\\Users\\guitz\\anaconda3\\Lib', 'c:\\Users\\guitz\\anaconda3', '', 'c:\\Users\\guitz\\anaconda3\\Lib\\site-packages', 'c:\\Users\\guitz\\anaconda3\\Lib\\site-packages\\win32', 'c:\\Users\\guitz\\anaconda3\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\guitz\\anaconda3\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\guitz\\OneDrive\\Área de Trabalho\\pyquant\\pyquant\\scripts']

# %%
import optimize as opt

# %%
import candle

# %%
google = candle.CandleFit('GOOG')

# %%
google.fit_hammer()
google.get_movings(10,20, 'test')
# Out:
# c:\Users\guitz\OneDrive\Área de Trabalho\pyquant\pyquant\scripts\candle.py:238: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\guitz\OneDrive\Área de Trabalho\pyquant\pyquant\scripts\candle.py:239: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\guitz\OneDrive\Área de Trabalho\pyquant\pyquant\scripts\candle.py:248: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
google.features
# Out:
#              open   high    low  close    volume  dividends  stock splits  \
# Date
# 2019-08-27  58.96  59.05  58.01  58.33  21544000       0.00          0.00
# 2019-08-28  58.02  58.75  57.80  58.48  16040000       0.00          0.00
# 2019-08-29  58.99  59.74  58.99  59.57  21768000       0.00          0.00
# 2019-08-30  59.86  59.86  59.12  59.34  22596000       0.00          0.00
# 2019-09-03  58.78  59.28  58.09  58.35  29598000       0.00          0.00
# ...           ...    ...    ...    ...       ...        ...           ...
# 2024-08-20 168.74 170.41 168.66 168.96  12622500       0.00          0.00
# 2024-08-21 166.99 168.64 166.57 167.63  15269600       0.00          0.00
# 2024-08-22 169.04 169.42 165.03 165.49  19123800       0.00          0.00
# 2024-08-23 166.55 167.95 165.66 167.43  14260500       0.00          0.00
# 2024-08-26 168.32 169.38 166.44 167.93  11634952       0.00          0.00
#
# ...

# %%
google.features

# %%
google.get_candle_features()

# %%
google.get_movings(5, 10, 'test')
# Out:
# c:\Users\guitz\OneDrive\Área de Trabalho\pyquant\pyquant\scripts\candle.py:238: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\guitz\OneDrive\Área de Trabalho\pyquant\pyquant\scripts\candle.py:239: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\guitz\OneDrive\Área de Trabalho\pyquant\pyquant\scripts\candle.py:248: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
google.features['test_5_10'].value_counts(normalize=True)
# Out:
# test_5_10
#  0   0.89
#  1   0.06
# -1   0.05
# Name: proportion, dtype: float64

# %%
backtest = google.get_trades('test_5_10',trade_period = 30, target_return=0.05)
# Out:
# c:\Users\guitz\OneDrive\Área de Trabalho\pyquant\pyquant\scripts\candle.py:404: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# c:\Users\guitz\OneDrive\Área de Trabalho\pyquant\pyquant\scripts\candle.py:404: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# c:\Users\guitz\OneDrive\Área de Trabalho\pyquant\pyquant\scripts\candle.py:404: PerformanceWarning:
#
# ...

# %%
backtest
# Out:
#              open   high    low  close  test_5_10  open_2  open_3  open_4  \
# Date
# 2019-09-04  58.77  59.11  58.48  59.00          1   60.34   60.13   59.69
# 2019-09-27  62.08  62.13  60.65  61.18          1   60.88   59.78   58.93
# 2019-09-30  60.98  61.23  60.55  60.88         -1   59.78   58.93   59.53
# 2019-10-11  61.04  61.35  60.62  60.70          1   60.95   61.99   62.48
# 2019-11-25  64.89  65.49  64.83  65.26         -1   65.68   65.28   64.98
# ...           ...    ...    ...    ...        ...     ...     ...     ...
# 2024-06-10 176.45 178.47 174.38 176.63          1  179.75  177.84  175.85
# 2024-06-21 178.49 182.51 178.06 180.26          1  181.15  184.20  185.65
# 2024-06-25 181.15 185.75 181.10 185.58          1  185.65  185.72  184.48
# 2024-07-16 188.96 190.34 185.12 185.50         -1  183.54  180.37  182.35
# 2024-08-15 162.21 163.52 161.49 163.17          1  167.00  168.74  166.99
#
# ...

# %%
google.summarize_results(backtest)
# Out:
#   Risk Reward Ratio  Profit    Loss    Net Profits Count Losses Count  \
# 0               0.5  346.53 -332.94  13.59            53           80
# 1               1.0  464.48 -407.47  57.00            69           62
# 2               1.5  530.12 -418.15 111.97            81           44
# 3               2.0  537.00 -388.39 148.61            82           32
#
#    Success Rate
# 0          0.40
# 1          0.53
# 2          0.65
# 3          0.72
